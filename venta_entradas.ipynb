# %% [markdown]
# <a href="https://colab.research.google.com/github/josueoteiza/repositorio/blob/main/venta_entradas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Club deportes "Buena ventura"

precio_menores = 2500
precio_adultos = 5000
precio_amayores = 1000


while True:
 print ("¡Bienvenidos a club de deportes Buena Ventura!")
 print ("1. menu")
 print ("2. pago")
 print ("3. anular compra")
 print ("4. salir del programa")
 opc = input ("seleccione una opcion: ")

 if opc == "1":
             cantidad_menores = int (input ("\nEntrada menores: de 5 a 12 años \nvalor entrada: $2.500 \n¿cuantas desea comprar?: "))
             cantidad_adultos = int (input ("\nEntrada adultos: de 13 a 64 años \nvalor entrada: $ 5.000 \n¿cuantas desea comprar?: "))
             cantidad_amayores = int (input ("\nEntrada adultos mayores: desde 65 años y mas \nvalor entrada: $ 1.000 \n¿cuantas desea comprar?: "))


 elif opc == "2":
       dia_semana = input ("\n1.lunes \n2.martes \n3.miercoles \n4.jueves \n5.viernes \nseleccione el dia que desea asistir: ")

       #dia semana viernes
       if dia_semana == "5":
         total_menores = cantidad_menores * precio_menores
         total_adultos = cantidad_adultos * precio_adultos
         total_amayores = cantidad_amayores * precio_amayores
         s1 = total_menores * (10 / 100)
         s2 = total_adultos * (5 / 100)
         subtotal = (cantidad_menores * precio_menores) + (cantidad_adultos * precio_adultos) + (cantidad_amayores * precio_amayores)
         descuentos = s1 + s2
         print ("")
         print ("       Entradas    ")
         print ("---------------------------------")
         print ("", cantidad_menores, "\tentrada menores\t", "\t$", total_menores)
         print ("", cantidad_adultos, "\tentrada adultos\t", "\t$", total_adultos)
         print ("", cantidad_amayores, "\tentrada adultos mayores", "$", total_amayores)
         print ("---------------------------------")
         print ("subtotal", subtotal)
         print ("descuentos", descuentos)
         print ("---------------------------------")
         total_pagar = float ((cantidad_menores * precio_menores)*0.9 + (cantidad_adultos * precio_adultos)*0.95 + (cantidad_amayores * precio_amayores))
         print ("el total a pagar es: $", total_pagar)
         print ("      ¡gracias por su compra!      ")
       elif dia_semana == "4" or dia_semana == "3" or dia_semana == "2" or dia_semana == "1":
         total_menores = cantidad_menores * precio_menores
         total_adultos = cantidad_adultos * precio_adultos
         total_amayores = cantidad_amayores * precio_amayores
         subtotal = (cantidad_menores * precio_menores) + (cantidad_adultos * precio_adultos) + (cantidad_amayores * precio_amayores)
         print ("")
         print ("       Entradas    ")
         print ("---------------------------------")
         print ("", cantidad_menores, "entrada menores", "$", total_menores)
         print ("", cantidad_adultos, "entrada adultos", "$", total_adultos)
         print ("", cantidad_amayores, "entrada adultos mayores", "$", total_amayores)
         print ("---------------------------------")
         print ("subtotal", "$", subtotal)
         print ("---------------------------------")
         total_pagar = float (cantidad_menores * precio_menores) + (cantidad_adultos * precio_adultos) + (cantidad_amayores * precio_amayores)
         print ("el total a pagar es: ", "$", total_pagar)
         print ("      ¡gracias por su compra!      ")
       else:
           print ("ingrese opcion correcta.")

 elif opc == "3":
     print ("compra anulada.")

 else:
     print ("salir del programa.")
     break
# Out:
# ¡Bienvenidos a club de deportes Buena Ventura!
# 1. menu
# 2. pago
# 3. anular compra
# 4. salir del programa
# seleccione una opcion: 1
#
# Entrada menores: de 5 a 12 años
# valor entrada: $2.500
# ¿cuantas desea comprar?: 2
#
# Entrada adultos: de 13 a 64 años
# valor entrada: $ 5.000
# ¿cuantas desea comprar?: 2
#
# Entrada adultos mayores: desde 65 años y mas
# valor entrada: $ 1.000
# ¿cuantas desea comprar?: 2
# ¡Bienvenidos a club de deportes Buena Ventura!
# 1. menu
# 2. pago
# 3. anular compra
# 4. salir del programa
# seleccione una opcion: 2
#
# 1.lunes
# 2.martes
# 3.miercoles
# 4.jueves
# 5.viernes
# seleccione el dia que desea asistir: 5
#
#        Entradas
# ---------------------------------
#  2 	entrada menores	 	$ 5000
#  2 	entrada adultos	 	$ 10000
#  2 	entrada adultos mayores $ 2000
# ---------------------------------
# subtotal 17000
# descuentos 1000.0
# ---------------------------------
# el total a pagar es: $ 16000.0
#       ¡gracias por su compra!
# ...

# %%
texto= input("Ingrese un texto")
mayusculas=texto.upper()
print("Texto en mayusculas:", mayusculas)
minusculas=texto.lower()
print("Texto en mayusculas:", minusculas)
# Out:
# Ingrese un textohola
# Texto en mayusculas: HOLA
# Texto en mayusculas: hola

# %%
dia = int(input('''Bienvenido al Club de Deportes Buena Ventura
                Indique el día para el que desea comprar entradas
                1. Lunes, Martes, Miércoles, Jueves, sábado o Domingo
                2. Viernes

                ingrese su día de preferencia: '''))

opcion = int(input('''Muy bien, estás más cerca de tu partido favorito
                    Seleccione una o más opciones de entrada

                    1. Compra de entradas
                    - Menores (5 a 12 años) $2500
                    - Adultos (13 a 64 años) $5000
                    - Adultos mayores (65 y más años) $1000
                    2. Anular compra
                    3. Terminar operación

                    Selecciones su opción: '''))

venta = True
descuento = 0

while venta:
    if opcion == 1 and dia == 1:
        menor = int(input("\nIndique la cantidad de entrada de menores: "))
        adulto = int(input("Indique la cantidad de entrada de adultos: "))
        adultoM = int(input("Indique la cantidad de entrada de adultos mayores: "))
        print(f'''Entradas
              --------------------------------------------------------
              {menor} entradas menores            ${menor * 2500}
              {adulto} entradas adultos           ${adulto * 5000}
              {adultoM} entradas adultos mayores  ${adultoM * 1000}
              --------------------------------------------------------
              Subtotal                            ${(menor*2500)+(adulto*5000)+(adultoM*1000)}
              Descuentos                          ${descuento}
              --------------------------------------------------------
                            Gracias por su compra!''')
        venta = False

    elif opcion == 1 and dia == 1:
        menor = int(input("\nIndique la cantidad de entrada de menores: "))
        adulto = int(input("Indique la cantidad de entrada de adultos: "))
        adultoM = int(input("Indique la cantidad de entrada de adultos mayores: "))
        descuento = ((menor*2500)*0.1)+((adulto*5000)*0.05)
        print(f'''Entradas
              --------------------------------------------------------
              {menor} entradas menores            ${menor * 2500}
              {adulto} entradas adultos           ${adulto * 5000}
              {adultoM} entradas adultos mayores  ${adultoM * 1000}
              --------------------------------------------------------
              Subtotal                            ${(menor*2500)+(adulto*5000)+(adultoM*1000)}
              Descuentos                          ${descuento}
              --------------------------------------------------------
                            Gracias por su compra!''')
        venta = False

    elif opcion == 2:
        opcion = int(input('''Muy bien, estás más cerca de tu partido favorito
                    Seleccione una o más opciones de entrada
                    1. Compra de entradas
                    - Menores (5 a 12 años) $2500
                    - Adultos (13 a 64 años) $5000
                    - Adultos mayores (65 y más años) $1000
                    2. Anular compra
                    3. Terminar operación'''))
    elif opcion == 2:
        print("\nGracias por preferir Club Deportivo Buena Ventura")
        venta = False
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f4a3725e1938> in <cell line: 1>()
# ----> 1 dia = int(input('''Bienvenido al Club de Deportes Buena Ventura
#       2                 Indique el día para el que desea comprar entradas
#       3                 1. Lunes, Martes, Miércoles, Jueves, sábado o Domingo
#       4                 2. Viernes
#       5
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
precio=[2500,5000,1000]
cost_total=0
prec_n=0
prec_a=0
prec_m=0
while True:
    print(".:TIPO DE ENTRADA:.")
    print("1.NIÑOS\t\t\t$2500")
    print("2.ADULTOS\t\t$5000")
    print("3.ADULTO MAYOR\t\t$1000")
    print("4.MOSTRAR TOTAL")
    print("5.CANCELAR COMPRA")
    print("6.SALIR")

    opc=int(input("¿QUE ENTRADAS DESEA?:\nOPC: "))
    if opc==1:
        can_n=int(input("¿cuantas entradas desea?: "))
        prec_n=can_n*precio[0]
        cost_total+=prec_n
        print("ENTRADAS AGREGADAS")
    elif opc==2:
        can_a=int(input("¿cuantas entradas desea?: "))
        prec_a=can_a*precio[1]
        cost_total+=prec_a
        print("ENTRADAS AGREGADAS")
    elif opc==3:
        can_m=int(input("¿cuantas entradas desea?: "))
        prec_m=can_m*precio[2]
        cost_total+=prec_m
        print("ENTRADAS AGREGADAS")
    elif opc==4:
        dia=str(input("¿PARA QUE DIA DESEA LAS ENTRADAS?: "))
        if dia=="viernes":
            print("::::BOLETA::::")
            print("TIPO\n CANTIDAD \nUNID \nTOTAL")
            print("-ENT. NIÑOS :",can_n,"\t",precio[0],"\t",prec_n,)
            print("-ENT. ADULTO:",can_a,"\t",precio[1],"\t",prec_a,)
            print("-ENT. ADUL M:",can_a,"\t",precio[2],"\t",prec_m,)
            print("--------------------------------")
            print("-TOTAL DESCUENTOS\t\t-",(prec_a*0.95)+(prec_n*0.9),)
            print("-COSTO TOTAL DE ENTRADAS \t",(prec_a*0.95)+(prec_n*0.9)+(prec_m))
            print("--------------------------------")
            print("GRACIAS POR SU COMPRA")
        else:
            print("::::BOLETA::::")
            print("TIPO\n CANTIDAD \nUNID \nTOTAL")
            print("-ENT. NIÑOS :",can_n,"\t",precio[0],"\t",prec_n,)
            print("-ENT. ADULTO:",can_a,"\t",precio[1],"\t",prec_a,)
            print("-ENT. ADUL M:",can_m,"\t",precio[2],"\t",prec_m,)
            print("--------------------------------")
            print("-TOTAL DESCUENTOS\t\t")
            print("-COSTO TOTAL DE ENTRADAS \t",prec_a+prec_n+prec_m,)
            print("--------------------------------")
            print("GRACIAS POR SU COMPRA")
        break
    elif opc==5:
        print("COMPRA CANCELADA")
    else:
        print("VUELVA PRONTO")
# Out:
# .:TIPO DE ENTRADA:.
# 1.NIÑOS			$2500
# 2.ADULTOS		$5000
# 3.ADULTO MAYOR		$1000
# 4.MOSTRAR TOTAL
# 5.CANCELAR COMPRA
# 6.SALIR
# ¿QUE ENTRADAS DESEA?:
# OPC: 1
# ¿cuantas entradas desea?: 2
# ENTRADAS AGREGADAS
# .:TIPO DE ENTRADA:.
# 1.NIÑOS			$2500
# 2.ADULTOS		$5000
# 3.ADULTO MAYOR		$1000
# 4.MOSTRAR TOTAL
# 5.CANCELAR COMPRA
# 6.SALIR
# ¿QUE ENTRADAS DESEA?:
# OPC: 3
# ¿cuantas entradas desea?: 2
# ENTRADAS AGREGADAS
# .:TIPO DE ENTRADA:.
# 1.NIÑOS			$2500
# 2.ADULTOS		$5000
# 3.ADULTO MAYOR		$1000
# 4.MOSTRAR TOTAL
# 5.CANCELAR COMPRA
# 6.SALIR
# ¿QUE ENTRADAS DESEA?:
# OPC: 5
# COMPRA CANCELADA
# .:TIPO DE ENTRADA:.
# 1.NIÑOS			$2500
# 2.ADULTOS		$5000
# 3.ADULTO MAYOR		$1000
# 4.MOSTRAR TOTAL
# 5.CANCELAR COMPRA
# 6.SALIR
# ¿QUE ENTRADAS DESEA?:
# OPC: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-004a0f2d8556> in <cell line: 6>()
# ...
